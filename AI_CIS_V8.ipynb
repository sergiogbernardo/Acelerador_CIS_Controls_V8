# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiogbernardo/Acelerador_CIS_Controls_V8/blob/main/AI_CIS_V8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instalação Gemini
# !pip install -q -U google-generativeai

# %%
import requests
from tabulate import tabulate
import google.generativeai as genai
from google.colab import userdata

# Função para exibir os controles em formato de tabela
def exibir_controles(data_controles):
    tabela_controles = []
    for controle in data_controles:
        if 'id' in controle and 'nome' in controle and 'descricao' in controle:
            tabela_controles.append([controle['id'], controle['nome'], controle['descricao']])
    print(tabulate(tabela_controles, headers=["ID", "Título", "Descrição"]))

# Arquivo Json Controles CIS V8
url_controles = "https://sergiogbernardo.github.io/ciscontrols_v8.json"

# Visualização dos dados dos controles
resposta_controles = requests.get(url_controles)
data_controles = resposta_controles.json()

# Configurações do chatbot Gemini
api_key = userdata.get("SECRET_KEY")
genai.configure(api_key=api_key)

generation_config = {
  "candidate_count": 1,
  "temperature": 0.5,
}

safety_settings = {
    'HATE': 'BLOCK_NONE',
    'HARASSMENT': 'BLOCK_NONE',
    'SEXUAL': 'BLOCK_NONE',
    'DANGEROUS': 'BLOCK_NONE'
}

model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                               generation_config=generation_config,
                               safety_settings=safety_settings)

# Introdução
print("Seja bem-vindo ao AI - CIS Controls V8")
print("Este programa foi projetado para auxiliar a avaliação dos controles do framework CIS Controls V8, aproveitando o poder do modelo Gemini para fornecer descrições detalhadas e benefícios associados a cada controle.")
print("Escolha abaixo um dos 18 controles do CIS Controls.")

# Loop principal
while True:
    # Exibindo os controles
    print("\nControles CIS disponíveis:")
    exibir_controles(data_controles)

    # Pedindo a resposta do usuário sobre o controle ou fim
    resposta_usuario_controle = input("\nPor favor, insira o ID do controle que deseja avaliar ou digite 'fim' para encerrar o programa: ")

    # Verificando se o usuário deseja encerrar o programa
    if resposta_usuario_controle.lower() == 'fim':
        print("Encerrando o programa...")
        break

    # Encontrando o controle escolhido pelo usuário
    controle_escolhido = None
    for controle in data_controles:
        if controle['id'] == int(resposta_usuario_controle):
            controle_escolhido = controle
            break

    # Verificando se o controle foi encontrado
    if controle_escolhido:
        num_subcontroles = len(controle_escolhido['subcontroles']) if 'subcontroles' in controle_escolhido else 0
        print(f"\nVocê escolheu o controle com o ID {resposta_usuario_controle}, este controle fala sobre \"{controle_escolhido['nome']}\" e possui um total de {num_subcontroles} subcontroles.")

        # Verificando se há subcontroles e incluindo a descrição de cada subcontrole
        if num_subcontroles > 0:
            print("\nSubcontroles:")
            tabela_subcontroles = []
            for subcontrole in controle_escolhido['subcontroles']:
                tabela_subcontroles.append([f"Subcontrole {subcontrole['id']}", subcontrole['descricao']])
            print(tabulate(tabela_subcontroles, headers=["", ""], tablefmt="grid"))

            # Chatbot analisando os subcontroles
            chat = model.start_chat(history=[])

            for subcontrole in controle_escolhido['subcontroles']:
                prompt = subcontrole['descricao']
                response = chat.send_message(prompt)
                print("\nResposta do chatbot:", response.text)


    else:
        print(f"O controle correspondente ao ID {resposta_usuario_controle} não foi encontrado. Por favor, digite um número de controle válido de 1 a 181.")
# Out:
# Seja bem-vindo ao AI - CIS Controls V8
# Este programa foi projetado para auxiliar a avaliação dos controles do framework CIS Controls V8, aproveitando o poder do modelo Gemini para fornecer descrições detalhadas e benefícios associados a cada controle.
# Escolha abaixo um dos 18 controles do CIS Controls.
#
# Controles CIS disponíveis:
#   ID  Título                                                 Descrição
# ----  -----------------------------------------------------  --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    1  Inventário e controle de ativos da empresa             Gerenciar ativamente (inventariar, rastrear e corrigir) todos os ativos da empresa (dispositivos de usuário final, incluindo portáteis e móveis; dispositivos de rede; dispositivos não informáticos / IoT - Internet das Coisas; e servidores) conectados à infraestrutura fisicamente, virtualmente, remotamente, e aqueles em ambientes de nuvem, para saber com precisão a totalidade de ativos que precisam ser monitorados e protegidos dentro da empresa. Isso também apoiará a identificação de ativos não autorizados e não gerenciados para remover ou corrigir.
#    2  Inventário e controle de ativos de software            Gerenciar ativamente (inventarie, rastreie e corrija) todos os softwares (sistemas operacionais e aplicações) na rede para que apenas softwares autorizados sejam instalados e possam ser executados, e que softwares não autorizados e não gerenciados sejam encontrados e impedidos de instalação ou execução.
#    3  Proteção de dados                                      Desenvolver processos e controles técnicos para identificar, classificar, manusear, reter e descartar dados com segurança.
#    4  Configuração segura de ativos corporativos e software  Estabelecer e manter a configuração segura de ativos corporativos e software.
#    5  Gestão de Contas                                       Usar processos e ferramentas para atribuir e gerenciar autorização para credenciais para contas de usuário, incluindo contas de administrador, bem como contas de serviço, para ativos corporativos e software.
#    6  Gerenciamento de controle de acesso                    Usar processos e ferramentas para criar, atribuir, gerenciar e revogar credenciais de acesso e privilégios para contas de usuário, administrador e serviço para ativos e software corporativos.
#    7  Gerenciamento Contínuo de Vulnerabilidade              Desenvolver um plano para avaliar e rastrear vulnerabilidades continuamente em todos os ativos corporativos dentro da infraestrutura da empresa, a fim de remediar e minimizar a janela de oportunidade para os invasores. Monitorar fontes da indústria pública e privada para novas informações sobre ameaças e vulnerabilidades.
#    8  Gerenciamento de registro de auditoria                 Coletar, alertar, analisar e reter logs de auditoria de eventos que podem ajudar a detectar, compreender ou recuperar-se de um ataque.
#    9  Controle de acesso de usuário                          Implementar políticas e procedimentos para controlar o acesso dos usuários aos sistemas e dados da empresa, garantindo que apenas indivíduos autorizados tenham permissão para acessar recursos específicos de acordo com suas funções e responsabilidades.
#   10  Gestão de vulnerabilidades                             Implementar um processo para identificar, avaliar e remediar vulnerabilidades de segurança em sistemas e aplicativos para reduzir o risco de exploração por parte de invasores.
#   11  Proteção de dados em trânsito e em repouso             Implementar medidas de segurança para proteger dados enquanto estão em trânsito entre sistemas e enquanto estão armazenados em dispositivos ou servidores.
#   12  Monitoramento e resposta de segurança                  Implementar sistemas de monitoramento contínuo e estabelecer procedimentos de resposta para identificar e responder rapidamente a eventos de segurança.
#   13  Segurança de redes                                     Proteger a infraestrutura de rede da organização contra ameaças internas e externas, garantindo a integridade, confidencialidade e disponibilidade dos dados e serviços.
#   14  Gerenciamento de dados                                 Gerenciar dados da organização de forma segura e eficiente ao longo de seu ciclo de vida, desde a criação até o descarte final.
#   15  Controle de acesso de usuário                          Garantir que apenas usuários autorizados tenham acesso aos recursos de sistema necessários para realizar suas responsabilidades atribuídas, e que os usuários não autorizados não tenham acesso a esses recursos.
#   16  Segurança de software de aplicativo                    Gerenciar o ciclo de vida da segurança de software desenvolvido, hospedado ou adquirido internamente para prevenir, detectar e corrigir os pontos fracos de segurança antes que eles afetem a empresa.
#   17  Gerenciamento de resposta a incidentes                 Estabelecer um programa para desenvolver e manter uma capacidade de resposta a incidentes (por exemplo, políticas, planos, procedimentos, funções definidas, treinamento e comunicações) para preparar, detectar e responder rapidamente a um ataque.
#   18  Teste de Penetração                                    Testar a eficácia e a resiliência dos ativos corporativos por meio da identificação e exploração de fraquezas nos controles (pessoas, processos e tecnologia) e da simulação dos objetivos e ações de um invasor.
#
# Por favor, insira o ID do controle que deseja avaliar ou digite 'fim' para encerrar o programa: 1
#
# Você escolheu o controle com o ID 1, este controle fala sobre "Inventário e controle de ativos da empresa" e possui um total de 5 subcontroles.
#
# Subcontroles:
# +-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +=================+===========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+
# | Subcontrole 1.1 | Estabelecer e manter um inventário preciso, detalhado e atualizado de todos os ativos da empresa com potencial para armazenar ou processar dados, incluindo: dispositivos de usuário final (incluindo portáteis e móveis), dispositivos de rede, não informática / IoT dispositivos e servidores. Certificar-se de que o inventário registre o endereço de rede (se estático), endereço de hardware, nome da máquina, proprietário do ativo corporativo, departamento para cada ativo e se o ativo foi aprovado para se conectar à rede. Para dispositivos móveis de usuário final, as ferramentas do tipo MDM podem oferecer suporte a esse processo, quando apropriado. Este inventário inclui ativos conectados à infraestrutura fisicamente, virtualmente, remotamente e aqueles dentro de ambientes de nuvem. Além disso, inclui ativos que são regularmente conectados à infraestrutura de rede da empresa, mesmo que não estejam sob o controle da empresa. Revisar e atualizar o inventário de todos os ativos da empresa semestralmente ou com maior frequência. |
# +-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Subcontrole 1.2 | Certificar-se de que existe um processo para lidar com ativos não autorizados semanalmente. A empresa pode escolher remover o ativo da rede, negar que o ativo se conecte remotamente à rede ou colocar o ativo em quarentena.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Subcontrole 1.3 | Utilizar uma ferramenta de descoberta ativa para identificar ativos conectados à rede da empresa. Configurar a ferramenta de descoberta ativa para executar diariamente ou com maior frequência.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Subcontrole 1.4 | Usar o log de DHCP em todos os servidores DHCP ou ferramentas de gerenciamento de endereço de protocolo da Internet (IP) para atualizar o inventário de ativos da empresa. Revisar e usar logs para atualizar o inventário de ativos da empresa semanalmente ou com maior frequência.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Subcontrole 1.5 | Usar uma ferramenta de descoberta passiva para identificar ativos conectados à rede da empresa. Revisar e Usar varreduras para atualizar o inventário de ativos da empresa pelo menos semanalmente ou com maior frequência.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +-----------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Resposta do chatbot: **Estabelecimento e Manutenção de um Inventário de Ativos**
#
# **Objetivo:**
#
# Estabelecer e manter um inventário preciso, detalhado e atualizado de todos os ativos da empresa com potencial para armazenar ou processar dados.
#
# **Âmbito:**
#
# * Dispositivos de usuário final (incluindo portáteis e móveis)
# * Dispositivos de rede
# * Dispositivos não informáticos/IoT
# * Servidores
# * Ativos conectados fisicamente, virtualmente, remotamente e em ambientes de nuvem
# * Ativos regularmente conectados à infraestrutura de rede da empresa, mesmo que não estejam sob seu controle
#
# **Informações do Inventário:**
#
# * Endereço de rede (se estático)
# * Endereço de hardware
# * Nome da máquina
# * Proprietário do ativo corporativo
# * Departamento
# * Aprovação para conexão à rede
#
# **Ferramentas de Suporte:**
#
# * Ferramentas de gerenciamento de dispositivos móveis (MDM) para dispositivos móveis de usuário final
#
# **Frequência de Revisão:**
#
# * Semestralmente ou com maior frequência
#
# **Procedimento:**
#
# 1. **Coletar informações:** Reunir informações de todas as fontes relevantes, incluindo:
#     * Departamentos de TI e de negócios
#     * Fornecedores
#     * Ferramentas de monitoramento
# 2. **Estabelecer um sistema de inventário:** Criar um banco de dados ou planilha para rastrear as informações do ativo.
# 3. **Revisar e atualizar regularmente:** Revisar e atualizar o inventário em intervalos regulares para garantir sua precisão.
# 4. **Auditar o inventário:** Conduzir auditorias regulares para verificar a precisão e integridade do inventário.
# 5. **Manter a segurança:** Implementar medidas de segurança para proteger as informações do inventário contra acesso não autorizado.
#
# **Benefícios:**
#
# * Melhora da segurança da rede
# * Redução de riscos de violação de dados
# * Conformidade regulatória
# * Otimização de recursos
# * Planejamento e tomada de decisão aprimorados
#
# Resposta do chatbot: **Processo de Manuseio de Ativos Não Autorizados**
#
# **Objetivo:**
#
# Estabelecer um processo para lidar com ativos não autorizados que são detectados na rede da empresa.
#
# **Frequência:**
#
# * Semanalmente
#
# **Procedimento:**
#
# 1. **Detectar ativos não autorizados:** Usar ferramentas de monitoramento e auditoria para identificar ativos não autorizados conectados à rede.
# 2. **Investigar e identificar:** Investigar o ativo não autorizado para determinar sua origem, propósito e potencial risco.
# 3. **Tomar medidas:** A empresa pode escolher uma das seguintes ações:
#     * Remover o ativo da rede
#     * Negar que o ativo se conecte remotamente à rede
#     * Colocar o ativo em quarentena
# 4. **Documentar e notificar:** Documentar a ação tomada e notificar as partes interessadas relevantes, como TI e segurança.
# 5. **Revisar e atualizar:** Revisar e atualizar o processo regularmente para garantir sua eficácia.
#
# **Benefícios:**
#
# * Melhora da segurança da rede
# * Redução de riscos de violação de dados
# * Conformidade regulatória
# * Proteção da integridade da rede
#
# **Observações:**
#
# * A empresa deve considerar o impacto potencial de cada ação antes de tomá-la.
# * A empresa deve ter um processo claro para determinar quais ativos são considerados não autorizados.
# * A empresa deve ter medidas de segurança em vigor para impedir que ativos não autorizados se conectem à rede.
#
# **Exemplo:**
#
# * Um ativo não autorizado é detectado na rede.
# * A equipe de TI investiga e determina que o ativo é um laptop pessoal de um funcionário que não foi aprovado para se conectar à rede.
# * A equipe de TI remove o laptop da rede e notifica o funcionário.
#
# **Lembrete:**
#
# É importante observar que este é apenas um exemplo de processo e as empresas podem adaptar o processo às suas necessidades e circunstâncias específicas.
#
# Resposta do chatbot: **Uso de uma Ferramenta de Descoberta Ativa**
#
# **Objetivo:**
#
# Utilizar uma ferramenta de descoberta ativa para identificar todos os ativos conectados à rede da empresa, incluindo aqueles que podem não estar visíveis por meio de outros métodos.
#
# **Frequência:**
#
# * Diariamente ou com maior frequência
#
# **Procedimento:**
#
# 1. **Selecionar uma ferramenta de descoberta ativa:** Escolher uma ferramenta que atenda às necessidades específicas da empresa, como varredura de rede, detecção de dispositivos IoT e identificação de vulnerabilidades.
# 2. **Configurar a ferramenta:** Configurar a ferramenta para executar varreduras regulares da rede em intervalos diários ou mais frequentes.
# 3. **Executar varreduras:** Executar varreduras regulares para identificar todos os ativos conectados à rede, incluindo dispositivos autorizados e não autorizados.
# 4. **Analisar resultados:** Analisar os resultados da varredura para identificar quaisquer ativos não autorizados ou vulneráveis.
# 5. **Tomar medidas:** Tomar as medidas apropriadas para lidar com ativos não autorizados ou vulneráveis, como removê-los da rede ou aplicar patches de segurança.
# 6. **Revisar e atualizar:** Revisar e atualizar o processo regularmente para garantir sua eficácia.
#
# **Benefícios:**
#
# * Detecção aprimorada de ativos
# * Identificação de dispositivos não autorizados e vulneráveis
# * Melhora da segurança da rede
# * Conformidade regulatória
#
# **Observações:**
#
# * A empresa deve considerar o impacto potencial das varreduras na rede e nos dispositivos conectados.
# * A empresa deve ter um processo claro para analisar os resultados da varredura e tomar as medidas apropriadas.
# * A empresa deve ter medidas de segurança em vigor para impedir que ativos não autorizados se conectem à rede.
#
# **Exemplo:**
#
# * Uma empresa usa uma ferramenta de descoberta ativa para executar varreduras diárias de sua rede.
# * A varredura identifica um dispositivo não autorizado conectado à rede.
# * A equipe de TI investiga e determina que o dispositivo é um ponto de acesso Wi-Fi não autorizado.
# * A equipe de TI remove o ponto de acesso da rede e notifica o departamento de segurança.
#
# **Lembrete:**
#
# É importante observar que este é apenas um exemplo de processo e as empresas podem adaptar o processo às suas necessidades e circunstâncias específicas.
#
# Resposta do chatbot: **Uso de Logs de DHCP para Atualizar o Inventário de Ativos**
#
# **Objetivo:**
#
# Usar logs de DHCP (Dynamic Host Configuration Protocol) e ferramentas de gerenciamento de endereço de protocolo da Internet (IP) para atualizar e manter um inventário preciso de ativos da empresa.
#
# **Frequência:**
#
# * Semanalmente ou com maior frequência
#
# **Procedimento:**
#
# 1. **Coletar logs de DHCP:** Coletar logs de DHCP de todos os servidores DHCP na rede da empresa.
# 2. **Analisar logs:** Analisar os logs de DHCP para identificar endereços IP atribuídos a dispositivos na rede.
# 3. **Mapear endereços IP para ativos:** Mapear os endereços IP identificados nos logs de DHCP para os ativos correspondentes usando ferramentas de gerenciamento de IP ou outras fontes de informações.
# 4. **Atualizar inventário de ativos:** Atualizar o inventário de ativos da empresa com as novas informações coletadas dos logs de DHCP.
# 5. **Revisar e atualizar regularmente:** Revisar e atualizar o inventário de ativos regularmente para garantir sua precisão.
#
# **Benefícios:**
#
# * Inventário de ativos mais preciso e abrangente
# * Detecção aprimorada de dispositivos não autorizados
# * Melhora da segurança da rede
# * Conformidade regulatória
#
# **Observações:**
#
# * A empresa deve ter um processo claro para analisar os logs de DHCP e mapear os endereços IP para os ativos correspondentes.
# * A empresa deve ter medidas de segurança em vigor para proteger os logs de DHCP contra acesso não autorizado.
# * A empresa deve considerar o impacto potencial da coleta e análise de logs de DHCP na rede e nos dispositivos conectados.
#
# **Exemplo:**
#
# * Uma empresa coleta logs de DHCP de seus servidores DHCP semanalmente.
# * Os logs são analisados e os endereços IP atribuídos são mapeados para os ativos correspondentes usando uma ferramenta de gerenciamento de IP.
# * O inventário de ativos da empresa é atualizado com as novas informações.
# * A empresa identifica um dispositivo não autorizado conectado à rede com base nas informações dos logs de DHCP.
#
# **Lembrete:**
#
# É importante observar que este é apenas um exemplo de processo e as empresas podem adaptar o processo às suas necessidades e circunstâncias específicas.
#
# Resposta do chatbot: **Uso de uma Ferramenta de Descoberta Passiva**
#
# **Objetivo:**
#
# Usar uma ferramenta de descoberta passiva para identificar ativos conectados à rede da empresa, incluindo aqueles que podem não estar visíveis por meio de outros métodos.
#
# **Frequência:**
#
# * Pelo menos semanalmente ou com maior frequência
#
# **Procedimento:**
#
# 1. **Selecionar uma ferramenta de descoberta passiva:** Escolher uma ferramenta que atenda às necessidades específicas da empresa, como monitoramento de tráfego de rede, detecção de dispositivos IoT e identificação de vulnerabilidades.
# 2. **Configurar a ferramenta:** Configurar a ferramenta para executar varreduras regulares da rede em intervalos semanais ou mais frequentes.
# 3. **Executar varreduras:** Executar varreduras regulares para identificar todos os ativos conectados à rede, incluindo dispositivos autorizados e não autorizados.
# 4. **Analisar resultados:** Analisar os resultados da varredura para identificar quaisquer ativos não autorizados ou vulneráveis.
# 5. **Tomar medidas:** Tomar as medidas apropriadas para lidar com ativos não autorizados ou vulneráveis, como removê-los da rede ou aplicar patches de segurança.
# 6. **Revisar e atualizar:** Revisar e atualizar o processo regularmente para garantir sua eficácia.
#
# **Benefícios:**
#
# * Detecção aprimorada de ativos
# * Identificação de dispositivos não autorizados e vulneráveis
# * Melhora da segurança da rede
# * Conformidade regulatória
#
# **Observações:**
#
# * A empresa deve considerar o impacto potencial das varreduras na rede e nos dispositivos conectados.
# * A empresa deve ter um processo claro para analisar os resultados da varredura e tomar as medidas apropriadas.
# * A empresa deve ter medidas de segurança em vigor para impedir que ativos não autorizados se conectem à rede.
#
# **Exemplo:**
#
# * Uma empresa usa uma ferramenta de descoberta passiva para executar varreduras semanais de sua rede.
# * A varredura identifica um dispositivo não autorizado conectado à rede.
# * A equipe de TI investiga e determina que o dispositivo é um ponto de acesso Wi-Fi não autorizado.
# * A equipe de TI remove o ponto de acesso da rede e notifica o departamento de segurança.
#
# **Lembrete:**
#
# É importante observar que este é apenas um exemplo de processo e as empresas podem adaptar o processo às suas necessidades e circunstâncias específicas.
#
# Controles CIS disponíveis:
#   ID  Título                                                 Descrição
# ----  -----------------------------------------------------  --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    1  Inventário e controle de ativos da empresa             Gerenciar ativamente (inventariar, rastrear e corrigir) todos os ativos da empresa (dispositivos de usuário final, incluindo portáteis e móveis; dispositivos de rede; dispositivos não informáticos / IoT - Internet das Coisas; e servidores) conectados à infraestrutura fisicamente, virtualmente, remotamente, e aqueles em ambientes de nuvem, para saber com precisão a totalidade de ativos que precisam ser monitorados e protegidos dentro da empresa. Isso também apoiará a identificação de ativos não autorizados e não gerenciados para remover ou corrigir.
#    2  Inventário e controle de ativos de software            Gerenciar ativamente (inventarie, rastreie e corrija) todos os softwares (sistemas operacionais e aplicações) na rede para que apenas softwares autorizados sejam instalados e possam ser executados, e que softwares não autorizados e não gerenciados sejam encontrados e impedidos de instalação ou execução.
#    3  Proteção de dados                                      Desenvolver processos e controles técnicos para identificar, classificar, manusear, reter e descartar dados com segurança.
#    4  Configuração segura de ativos corporativos e software  Estabelecer e manter a configuração segura de ativos corporativos e software.
#    5  Gestão de Contas                                       Usar processos e ferramentas para atribuir e gerenciar autorização para credenciais para contas de usuário, incluindo contas de administrador, bem como contas de serviço, para ativos corporativos e software.
#    6  Gerenciamento de controle de acesso                    Usar processos e ferramentas para criar, atribuir, gerenciar e revogar credenciais de acesso e privilégios para contas de usuário, administrador e serviço para ativos e software corporativos.
#    7  Gerenciamento Contínuo de Vulnerabilidade              Desenvolver um plano para avaliar e rastrear vulnerabilidades continuamente em todos os ativos corporativos dentro da infraestrutura da empresa, a fim de remediar e minimizar a janela de oportunidade para os invasores. Monitorar fontes da indústria pública e privada para novas informações sobre ameaças e vulnerabilidades.
#    8  Gerenciamento de registro de auditoria                 Coletar, alertar, analisar e reter logs de auditoria de eventos que podem ajudar a detectar, compreender ou recuperar-se de um ataque.
#    9  Controle de acesso de usuário                          Implementar políticas e procedimentos para controlar o acesso dos usuários aos sistemas e dados da empresa, garantindo que apenas indivíduos autorizados tenham permissão para acessar recursos específicos de acordo com suas funções e responsabilidades.
#   10  Gestão de vulnerabilidades                             Implementar um processo para identificar, avaliar e remediar vulnerabilidades de segurança em sistemas e aplicativos para reduzir o risco de exploração por parte de invasores.
#   11  Proteção de dados em trânsito e em repouso             Implementar medidas de segurança para proteger dados enquanto estão em trânsito entre sistemas e enquanto estão armazenados em dispositivos ou servidores.
#   12  Monitoramento e resposta de segurança                  Implementar sistemas de monitoramento contínuo e estabelecer procedimentos de resposta para identificar e responder rapidamente a eventos de segurança.
#   13  Segurança de redes                                     Proteger a infraestrutura de rede da organização contra ameaças internas e externas, garantindo a integridade, confidencialidade e disponibilidade dos dados e serviços.
#   14  Gerenciamento de dados                                 Gerenciar dados da organização de forma segura e eficiente ao longo de seu ciclo de vida, desde a criação até o descarte final.
#   15  Controle de acesso de usuário                          Garantir que apenas usuários autorizados tenham acesso aos recursos de sistema necessários para realizar suas responsabilidades atribuídas, e que os usuários não autorizados não tenham acesso a esses recursos.
#   16  Segurança de software de aplicativo                    Gerenciar o ciclo de vida da segurança de software desenvolvido, hospedado ou adquirido internamente para prevenir, detectar e corrigir os pontos fracos de segurança antes que eles afetem a empresa.
#   17  Gerenciamento de resposta a incidentes                 Estabelecer um programa para desenvolver e manter uma capacidade de resposta a incidentes (por exemplo, políticas, planos, procedimentos, funções definidas, treinamento e comunicações) para preparar, detectar e responder rapidamente a um ataque.
#   18  Teste de Penetração                                    Testar a eficácia e a resiliência dos ativos corporativos por meio da identificação e exploração de fraquezas nos controles (pessoas, processos e tecnologia) e da simulação dos objetivos e ações de um invasor.
#
# Por favor, insira o ID do controle que deseja avaliar ou digite 'fim' para encerrar o programa: fim
# Encerrando o programa...
